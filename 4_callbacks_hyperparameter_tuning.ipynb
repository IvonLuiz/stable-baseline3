# %% [markdown]
# <a href="https://colab.research.google.com/github/araffin/rl-tutorial-jnrr19/blob/sb3/4_callbacks_hyperparameter_tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stable Baselines3 Tutorial - Callbacks and hyperparameter tuning
#
# Github repo: https://github.com/araffin/rl-tutorial-jnrr19/tree/sb3/
#
# Stable-Baselines3: https://github.com/DLR-RM/stable-baselines3
#
# Documentation: https://stable-baselines3.readthedocs.io/en/master/
#
# SB3-Contrib: https://github.com/Stable-Baselines-Team/stable-baselines3-contrib
#
# RL Baselines3 zoo: https://github.com/DLR-RM/rl-baselines3-zoo
#
#
# ## Introduction
#
# In this notebook, you will learn how to use [Callbacks](https://stable-baselines3.readthedocs.io/en/master/guide/callbacks.html) which allow to do monitoring, auto saving, model manipulation, progress bars, ...
#
#
# You will also see that finding good hyperparameters is key to success in RL.
#
# ## Install Dependencies and Stable Baselines3 Using Pip

# %%
# for autoformatting
# %load_ext jupyter_black

# %%
# !apt install swig
# !pip install "stable-baselines3[extra]>=2.0.0a4"
# Out:
# 'apt' n�o � reconhecido como um comando interno
# ou externo, um programa oper�vel ou um arquivo em lotes.
# Requirement already satisfied: stable-baselines3>=2.0.0a4 in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (2.5.0a1)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.0.0)
# Requirement already satisfied: numpy<3.0,>=1.20 in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.2.1)
# Requirement already satisfied: torch<3.0,>=2.3 in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.5.1)
# Requirement already satisfied: cloudpickle in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.1.1)
# Requirement already satisfied: pandas in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.2.3)
# Requirement already satisfied: matplotlib in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.10.0)
# Requirement already satisfied: opencv-python in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (4.10.0.84)
# Requirement already satisfied: pygame in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (2.18.0)
# Requirement already satisfied: psutil in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (6.1.1)
# Requirement already satisfied: tqdm in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (4.67.1)
# Requirement already satisfied: rich in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (13.9.4)
# Requirement already satisfied: ale-py>=0.9.0 in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (0.10.1)
# Requirement already satisfied: pillow in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (11.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (0.0.4)
# Requirement already satisfied: absl-py>=0.4 in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.69.0)
# Requirement already satisfied: markdown>=2.6.8 in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.7)
# Requirement already satisfied: packaging in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (24.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (5.29.3)
# Requirement already satisfied: setuptools>=41.0.0 in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (65.5.0)
# Requirement already satisfied: six>1.9 in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.1.3)
# Requirement already satisfied: filelock in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.16.1)
# Requirement already satisfied: networkx in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.4.2)
# Requirement already satisfied: jinja2 in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.1.5)
# Requirement already satisfied: fsspec in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2024.12.0)
# Requirement already satisfied: sympy==1.13.1 in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from pandas->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from pandas->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2024.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (2.19.1)
# Requirement already satisfied: colorama in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from tqdm->stable-baselines3[extra]>=2.0.0a4) (0.4.6)
# Requirement already satisfied: mdurl~=0.1 in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a4) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\code\data science\stable-baseline3\.venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.0.2)
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import gymnasium as gym
from stable_baselines3 import A2C, SAC, PPO, TD3

# %% [markdown]
# # The importance of hyperparameter tuning
#
# When compared with Supervised Learning, Deep Reinforcement Learning is far more sensitive to the choice of hyper-parameters such as learning rate, number of neurons, number of layers, optimizer ... etc.
# Poor choice of hyper-parameters can lead to poor/unstable convergence. This challenge is compounded by the variability in performance across random seeds (used to initialize the network weights and the environment).
#
# Here we demonstrate on a toy example the [Soft Actor Critic](https://arxiv.org/abs/1801.01290) algorithm applied in the Pendulum environment. Note the change in performance between the default and "tuned" parameters.

# %%
import numpy as np

from stable_baselines3.common.evaluation import evaluate_policy

# %%
eval_env = gym.make("Pendulum-v1")

# %%
default_model = SAC(
    "MlpPolicy",
    "Pendulum-v1",
    verbose=1,
    seed=0,
    batch_size=64,
    policy_kwargs=dict(net_arch=[64, 64]),
).learn(8000)
# Out:
# Using cpu device
# Creating environment from the given name 'Pendulum-v1'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.38e+03 |
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 264       |
# |    time_elapsed    | 3         |
# |    total_timesteps | 800       |
# | train/             |           |
# |    actor_loss      | 18.7      |
# |    critic_loss     | 1.46      |
# |    ent_coef        | 0.811     |
# |    ent_coef_loss   | -0.346    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 699       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.45e+03 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 252       |
# |    time_elapsed    | 6         |
# |    total_timesteps | 1600      |
# | train/             |           |
# |    actor_loss      | 43.3      |
# |    critic_loss     | 0.966     |
# |    ent_coef        | 0.645     |
# |    ent_coef_loss   | -0.661    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1499      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.44e+03 |
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 247       |
# |    time_elapsed    | 9         |
# |    total_timesteps | 2400      |
# | train/             |           |
# |    actor_loss      | 69.7      |
# |    critic_loss     | 0.752     |
# |    ent_coef        | 0.52      |
# |    ent_coef_loss   | -0.803    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2299      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.35e+03 |
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 244       |
# |    time_elapsed    | 13        |
# |    total_timesteps | 3200      |
# | train/             |           |
# |    actor_loss      | 81.1      |
# |    critic_loss     | 6.28      |
# |    ent_coef        | 0.429     |
# |    ent_coef_loss   | -0.596    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3099      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.33e+03 |
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 242       |
# |    time_elapsed    | 16        |
# |    total_timesteps | 4000      |
# | train/             |           |
# |    actor_loss      | 102       |
# |    critic_loss     | 3.37      |
# |    ent_coef        | 0.364     |
# |    ent_coef_loss   | -0.597    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3899      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.34e+03 |
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 241       |
# |    time_elapsed    | 19        |
# |    total_timesteps | 4800      |
# | train/             |           |
# |    actor_loss      | 114       |
# |    critic_loss     | 3.05      |
# |    ent_coef        | 0.31      |
# |    ent_coef_loss   | -0.598    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 4699      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 240       |
# |    time_elapsed    | 23        |
# |    total_timesteps | 5600      |
# | train/             |           |
# |    actor_loss      | 133       |
# |    critic_loss     | 2.52      |
# |    ent_coef        | 0.254     |
# |    ent_coef_loss   | -0.836    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 5499      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.23e+03 |
# | time/              |           |
# |    episodes        | 32        |
# |    fps             | 236       |
# |    time_elapsed    | 27        |
# |    total_timesteps | 6400      |
# | train/             |           |
# |    actor_loss      | 141       |
# |    critic_loss     | 2.36      |
# |    ent_coef        | 0.205     |
# |    ent_coef_loss   | -0.325    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 6299      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.16e+03 |
# | time/              |           |
# |    episodes        | 36        |
# |    fps             | 235       |
# |    time_elapsed    | 30        |
# |    total_timesteps | 7200      |
# | train/             |           |
# |    actor_loss      | 163       |
# |    critic_loss     | 3.12      |
# |    ent_coef        | 0.188     |
# |    ent_coef_loss   | -0.0517   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 7099      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.11e+03 |
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 234       |
# |    time_elapsed    | 34        |
# |    total_timesteps | 8000      |
# | train/             |           |
# |    actor_loss      | 165       |
# |    critic_loss     | 2.17      |
# |    ent_coef        | 0.199     |
# |    ent_coef_loss   | 0.14      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 7899      |
# ----------------------------------

# %%
mean_reward, std_reward = evaluate_policy(default_model, eval_env, n_eval_episodes=100)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# d:\Code\Data Science\stable-baseline3\.venv\Lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward:-411.48 +/- 106.00

# %%
tuned_model = SAC(
    "MlpPolicy",
    "Pendulum-v1",
    batch_size=256,
    verbose=1,
    policy_kwargs=dict(net_arch=[256, 256]),
    seed=0,
).learn(8000)
# Out:
# Using cpu device
# Creating environment from the given name 'Pendulum-v1'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.37e+03 |
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 165       |
# |    time_elapsed    | 4         |
# |    total_timesteps | 800       |
# | train/             |           |
# |    actor_loss      | 22.4      |
# |    critic_loss     | 0.27      |
# |    ent_coef        | 0.812     |
# |    ent_coef_loss   | -0.341    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 699       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.39e+03 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 154       |
# |    time_elapsed    | 10        |
# |    total_timesteps | 1600      |
# | train/             |           |
# |    actor_loss      | 45.7      |
# |    critic_loss     | 0.165     |
# |    ent_coef        | 0.649     |
# |    ent_coef_loss   | -0.572    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1499      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.31e+03 |
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 150       |
# |    time_elapsed    | 15        |
# |    total_timesteps | 2400      |
# | train/             |           |
# |    actor_loss      | 62.1      |
# |    critic_loss     | 0.267     |
# |    ent_coef        | 0.535     |
# |    ent_coef_loss   | -0.597    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2299      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -1.2e+03 |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 149      |
# |    time_elapsed    | 21       |
# |    total_timesteps | 3200     |
# | train/             |          |
# |    actor_loss      | 76       |
# |    critic_loss     | 0.603    |
# |    ent_coef        | 0.455    |
# |    ent_coef_loss   | -0.372   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3099     |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.01e+03 |
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 148       |
# |    time_elapsed    | 26        |
# |    total_timesteps | 4000      |
# | train/             |           |
# |    actor_loss      | 76.6      |
# |    critic_loss     | 0.673     |
# |    ent_coef        | 0.394     |
# |    ent_coef_loss   | -0.568    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3899      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -858     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 146      |
# |    time_elapsed    | 32       |
# |    total_timesteps | 4800     |
# | train/             |          |
# |    actor_loss      | 80.2     |
# |    critic_loss     | 0.676    |
# |    ent_coef        | 0.335    |
# |    ent_coef_loss   | -0.625   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -762     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 145      |
# |    time_elapsed    | 38       |
# |    total_timesteps | 5600     |
# | train/             |          |
# |    actor_loss      | 73.1     |
# |    critic_loss     | 1.33     |
# |    ent_coef        | 0.277    |
# |    ent_coef_loss   | -0.61    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -682     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 145      |
# |    time_elapsed    | 44       |
# |    total_timesteps | 6400     |
# | train/             |          |
# |    actor_loss      | 79.4     |
# |    critic_loss     | 0.943    |
# |    ent_coef        | 0.228    |
# |    ent_coef_loss   | -0.494   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -620     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 145      |
# |    time_elapsed    | 49       |
# |    total_timesteps | 7200     |
# | train/             |          |
# |    actor_loss      | 71.7     |
# |    critic_loss     | 0.997    |
# |    ent_coef        | 0.19     |
# |    ent_coef_loss   | -0.756   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -568     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 142      |
# |    time_elapsed    | 55       |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | 70.5     |
# |    critic_loss     | 1.12     |
# |    ent_coef        | 0.158    |
# |    ent_coef_loss   | -0.466   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7899     |
# ---------------------------------

# %%
mean_reward, std_reward = evaluate_policy(tuned_model, eval_env, n_eval_episodes=100)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-134.75 +/- 82.62

# %% [markdown]
# Exploring hyperparameter tuning is out of the scope (and time schedule) of this tutorial. However, you need to know that we provide tuned hyperparameter in the [rl zoo](https://github.com/DLR-RM/rl-baselines3-zoo) as well as automatic hyperparameter optimization using [Optuna](https://github.com/pfnet/optuna).

# %% [markdown]
# # Callbacks
#
#
# Please read the [documentation](https://stable-baselines3.readthedocs.io/en/master/guide/callbacks.html). Although Stable-Baselines3 provides you with a callback collection (e.g. for creating checkpoints or for evaluation), we are going to re-implement some so you can get a good understanding of how they work.
#
# To build a custom callback, you need to create a class that derives from `BaseCallback`. This will give you access to events (`_on_training_start`, `_on_step()`) and useful variables (like `self.model` for the RL model).
#
# `_on_step` returns a boolean value for whether or not the training should continue.
#
# Thanks to the access to the models variables, in particular `self.model`, we are able to even change the parameters of the model without halting the training, or changing the model's code.

# %%
from stable_baselines3.common.callbacks import BaseCallback

# %%
class CustomCallback(BaseCallback):
    """
    A custom callback that derives from ``BaseCallback``.

    :param verbose: (int) Verbosity level 0: not output 1: info 2: debug
    """

    def __init__(self, verbose=0):
        super().__init__(verbose)
        # Those variables will be accessible in the callback
        # (they are defined in the base class)
        # The RL model
        # self.model = None  # type: BaseRLModel
        # An alias for self.model.get_env(), the environment used for training
        # self.training_env = None  # type: Union[gym.Env, VecEnv, None]
        # Number of time the callback was called
        # self.n_calls = 0  # type: int
        # self.num_timesteps = 0  # type: int
        # local and global variables
        # self.locals = None  # type: Dict[str, Any]
        # self.globals = None  # type: Dict[str, Any]
        # The logger object, used to report things in the terminal
        # self.logger = None  # type: logger.Logger
        # # Sometimes, for event callback, it is useful
        # # to have access to the parent object
        # self.parent = None  # type: Optional[BaseCallback]

    def _on_training_start(self) -> None:
        """
        This method is called before the first rollout starts.
        """
        pass

    def _on_rollout_start(self) -> None:
        """
        A rollout is the collection of environment interaction
        using the current policy.
        This event is triggered before collecting new samples.
        """
        pass

    def _on_step(self) -> bool:
        """
        This method will be called by the model after each call to `env.step()`.

        For child callback (of an `EventCallback`), this will be called
        when the event is triggered.

        :return: (bool) If the callback returns False, training is aborted early.
        """
        return True

    def _on_rollout_end(self) -> None:
        """
        This event is triggered before updating the policy.
        """
        pass

    def _on_training_end(self) -> None:
        """
        This event is triggered before exiting the `learn()` method.
        """
        pass

# %% [markdown]
# Here we have a simple callback that can only be called twice:

# %%
class SimpleCallback(BaseCallback):
    """
    a simple callback that can only be called twice

    :param verbose: (int) Verbosity level 0: not output 1: info 2: debug
    """

    def __init__(self, verbose=0):
        super(SimpleCallback, self).__init__(verbose)
        self._called = False

    def _on_step(self):
        if not self._called:
            print("callback - first call")
            self._called = True
            return True  # returns True, training continues.
        print("callback - second call")
        return False  # returns False, training stops.

# %%
model = SAC("MlpPolicy", "Pendulum-v1", verbose=1)
model.learn(8000, callback=SimpleCallback())
# Out:
# Using cpu device
# Creating environment from the given name 'Pendulum-v1'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# callback - first call
# callback - second call

# %% [markdown]
# ## First example: Auto saving best model
# In RL, it is quite useful to keep a clean version of a model as you are training, as we can end up with burn-in of a bad policy. This is a typical use case for callback, as they can call the save function of the model, and observe the training over time.
#
# Using the monitoring wrapper, we can save statistics of the environment, and use them to determine the mean training reward.
# This allows us to save the best model while training.
#
# Note that this is not the proper way of evaluating an RL agent, you should create an test environment and evaluate the agent performance in the callback (cf `EvalCallback`). For simplicity, we will be using the training reward as a proxy.

# %%
import os

import numpy as np

from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.results_plotter import load_results, ts2xy

# %%
class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """

    def __init__(self, check_freq, log_dir, verbose=1):
        super().__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, "best_model")
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:

            # Retrieve training reward
            x, y = ts2xy(load_results(self.log_dir), "timesteps")
            if len(x) > 0:
                # Mean training reward over the last 100 episodes
                mean_reward = np.mean(y[-100:])
                if self.verbose > 0:
                    print("Num timesteps: {}".format(self.num_timesteps))
                    print(
                        "Best mean reward: {:.2f} - Last mean reward per episode: {:.2f}".format(
                            self.best_mean_reward, mean_reward
                        )
                    )

                # New best model, you could save the agent here
                if mean_reward > self.best_mean_reward:
                    self.best_mean_reward = mean_reward
                    # Example for saving best model
                    if self.verbose > 0:
                        print("Saving new best model at {} timesteps".format(x[-1]))
                        print("Saving new best model to {}.zip".format(self.save_path))
                    self.model.save(self.save_path)

        return True

# %%
# Create log dir
log_dir = "/tmp/gym/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = make_vec_env("CartPole-v1", n_envs=1, monitor_dir=log_dir)
# it is equivalent to:
# env = gym.make('CartPole-v1')
# env = Monitor(env, log_dir)
# env = DummyVecEnv([lambda: env])

# Create Callback
callback = SaveOnBestTrainingRewardCallback(check_freq=20, log_dir=log_dir, verbose=1)

model = A2C("MlpPolicy", env, verbose=0)
model.learn(total_timesteps=5000, callback=callback)
# Out:
# Num timesteps: 100
# Best mean reward: -inf - Last mean reward per episode: 90.00
# Saving new best model at 90 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 120
# Best mean reward: 90.00 - Last mean reward per episode: 90.00
# Num timesteps: 140
# Best mean reward: 90.00 - Last mean reward per episode: 90.00
# Num timesteps: 160
# Best mean reward: 90.00 - Last mean reward per episode: 77.00
# Num timesteps: 180
# Best mean reward: 90.00 - Last mean reward per episode: 77.00
# Num timesteps: 200
# Best mean reward: 90.00 - Last mean reward per episode: 77.00
# Num timesteps: 220
# Best mean reward: 90.00 - Last mean reward per episode: 70.67
# Num timesteps: 240
# Best mean reward: 90.00 - Last mean reward per episode: 70.67
# Num timesteps: 260
# Best mean reward: 90.00 - Last mean reward per episode: 60.50
# Num timesteps: 280
# Best mean reward: 90.00 - Last mean reward per episode: 60.50
# Num timesteps: 300
# Best mean reward: 90.00 - Last mean reward per episode: 56.80
# Num timesteps: 320
# Best mean reward: 90.00 - Last mean reward per episode: 56.80
# Num timesteps: 340
# Best mean reward: 90.00 - Last mean reward per episode: 56.33
# Num timesteps: 360
# Best mean reward: 90.00 - Last mean reward per episode: 56.33
# Num timesteps: 380
# Best mean reward: 90.00 - Last mean reward per episode: 52.57
# Num timesteps: 400
# Best mean reward: 90.00 - Last mean reward per episode: 49.50
# Num timesteps: 420
# Best mean reward: 90.00 - Last mean reward per episode: 49.50
# Num timesteps: 440
# Best mean reward: 90.00 - Last mean reward per episode: 48.11
# Num timesteps: 460
# Best mean reward: 90.00 - Last mean reward per episode: 44.70
# Num timesteps: 480
# Best mean reward: 90.00 - Last mean reward per episode: 44.70
# Num timesteps: 500
# Best mean reward: 90.00 - Last mean reward per episode: 43.91
# Num timesteps: 520
# Best mean reward: 90.00 - Last mean reward per episode: 42.75
# Num timesteps: 540
# Best mean reward: 90.00 - Last mean reward per episode: 42.75
# Num timesteps: 560
# Best mean reward: 90.00 - Last mean reward per episode: 42.08
# Num timesteps: 580
# Best mean reward: 90.00 - Last mean reward per episode: 42.08
# Num timesteps: 600
# Best mean reward: 90.00 - Last mean reward per episode: 42.79
# Num timesteps: 620
# Best mean reward: 90.00 - Last mean reward per episode: 42.79
# Num timesteps: 640
# Best mean reward: 90.00 - Last mean reward per episode: 42.27
# Num timesteps: 660
# Best mean reward: 90.00 - Last mean reward per episode: 42.27
# Num timesteps: 680
# Best mean reward: 90.00 - Last mean reward per episode: 41.44
# Num timesteps: 700
# Best mean reward: 90.00 - Last mean reward per episode: 41.44
# Num timesteps: 720
# Best mean reward: 90.00 - Last mean reward per episode: 41.41
# Num timesteps: 740
# Best mean reward: 90.00 - Last mean reward per episode: 40.89
# Num timesteps: 760
# Best mean reward: 90.00 - Last mean reward per episode: 40.89
# Num timesteps: 780
# Best mean reward: 90.00 - Last mean reward per episode: 40.89
# Num timesteps: 800
# Best mean reward: 90.00 - Last mean reward per episode: 40.89
# Num timesteps: 820
# Best mean reward: 90.00 - Last mean reward per episode: 42.32
# Num timesteps: 840
# Best mean reward: 90.00 - Last mean reward per episode: 41.60
# Num timesteps: 860
# Best mean reward: 90.00 - Last mean reward per episode: 41.60
# Num timesteps: 880
# Best mean reward: 90.00 - Last mean reward per episode: 41.57
# Num timesteps: 900
# Best mean reward: 90.00 - Last mean reward per episode: 41.57
# Num timesteps: 920
# Best mean reward: 90.00 - Last mean reward per episode: 41.82
# Num timesteps: 940
# Best mean reward: 90.00 - Last mean reward per episode: 41.82
# Num timesteps: 960
# Best mean reward: 90.00 - Last mean reward per episode: 41.82
# Num timesteps: 980
# Best mean reward: 90.00 - Last mean reward per episode: 41.82
# Num timesteps: 1000
# Best mean reward: 90.00 - Last mean reward per episode: 43.00
# Num timesteps: 1020
# Best mean reward: 90.00 - Last mean reward per episode: 42.12
# Num timesteps: 1040
# Best mean reward: 90.00 - Last mean reward per episode: 42.12
# Num timesteps: 1060
# Best mean reward: 90.00 - Last mean reward per episode: 42.24
# Num timesteps: 1080
# Best mean reward: 90.00 - Last mean reward per episode: 42.24
# Num timesteps: 1100
# Best mean reward: 90.00 - Last mean reward per episode: 41.77
# Num timesteps: 1120
# Best mean reward: 90.00 - Last mean reward per episode: 41.11
# Num timesteps: 1140
# Best mean reward: 90.00 - Last mean reward per episode: 41.11
# Num timesteps: 1160
# Best mean reward: 90.00 - Last mean reward per episode: 41.18
# Num timesteps: 1180
# Best mean reward: 90.00 - Last mean reward per episode: 41.18
# Num timesteps: 1200
# Best mean reward: 90.00 - Last mean reward per episode: 41.07
# Num timesteps: 1220
# Best mean reward: 90.00 - Last mean reward per episode: 41.07
# Num timesteps: 1240
# Best mean reward: 90.00 - Last mean reward per episode: 41.13
# Num timesteps: 1260
# Best mean reward: 90.00 - Last mean reward per episode: 41.13
# Num timesteps: 1280
# Best mean reward: 90.00 - Last mean reward per episode: 41.13
# Num timesteps: 1300
# Best mean reward: 90.00 - Last mean reward per episode: 41.87
# Num timesteps: 1320
# Best mean reward: 90.00 - Last mean reward per episode: 41.22
# Num timesteps: 1340
# Best mean reward: 90.00 - Last mean reward per episode: 41.22
# Num timesteps: 1360
# Best mean reward: 90.00 - Last mean reward per episode: 41.03
# Num timesteps: 1380
# Best mean reward: 90.00 - Last mean reward per episode: 41.03
# Num timesteps: 1400
# Best mean reward: 90.00 - Last mean reward per episode: 40.65
# Num timesteps: 1420
# Best mean reward: 90.00 - Last mean reward per episode: 40.29
# Num timesteps: 1440
# Best mean reward: 90.00 - Last mean reward per episode: 39.83
# Num timesteps: 1460
# Best mean reward: 90.00 - Last mean reward per episode: 39.83
# Num timesteps: 1480
# Best mean reward: 90.00 - Last mean reward per episode: 39.83
# Num timesteps: 1500
# Best mean reward: 90.00 - Last mean reward per episode: 40.11
# Num timesteps: 1520
# Best mean reward: 90.00 - Last mean reward per episode: 39.97
# Num timesteps: 1540
# Best mean reward: 90.00 - Last mean reward per episode: 39.97
# Num timesteps: 1560
# Best mean reward: 90.00 - Last mean reward per episode: 39.97
# Num timesteps: 1580
# Best mean reward: 90.00 - Last mean reward per episode: 40.03
# Num timesteps: 1600
# Best mean reward: 90.00 - Last mean reward per episode: 40.00
# Num timesteps: 1620
# Best mean reward: 90.00 - Last mean reward per episode: 40.00
# Num timesteps: 1640
# Best mean reward: 90.00 - Last mean reward per episode: 39.95
# Num timesteps: 1660
# Best mean reward: 90.00 - Last mean reward per episode: 39.95
# Num timesteps: 1680
# Best mean reward: 90.00 - Last mean reward per episode: 39.95
# Num timesteps: 1700
# Best mean reward: 90.00 - Last mean reward per episode: 40.17
# Num timesteps: 1720
# Best mean reward: 90.00 - Last mean reward per episode: 40.17
# Num timesteps: 1740
# Best mean reward: 90.00 - Last mean reward per episode: 40.12
# Num timesteps: 1760
# Best mean reward: 90.00 - Last mean reward per episode: 39.82
# Num timesteps: 1780
# Best mean reward: 90.00 - Last mean reward per episode: 39.82
# Num timesteps: 1800
# Best mean reward: 90.00 - Last mean reward per episode: 39.60
# Num timesteps: 1820
# Best mean reward: 90.00 - Last mean reward per episode: 39.46
# Num timesteps: 1840
# Best mean reward: 90.00 - Last mean reward per episode: 39.46
# Num timesteps: 1860
# Best mean reward: 90.00 - Last mean reward per episode: 39.28
# Num timesteps: 1880
# Best mean reward: 90.00 - Last mean reward per episode: 39.28
# Num timesteps: 1900
# Best mean reward: 90.00 - Last mean reward per episode: 39.21
# Num timesteps: 1920
# Best mean reward: 90.00 - Last mean reward per episode: 39.21
# Num timesteps: 1940
# Best mean reward: 90.00 - Last mean reward per episode: 39.24
# Num timesteps: 1960
# Best mean reward: 90.00 - Last mean reward per episode: 38.98
# Num timesteps: 1980
# Best mean reward: 90.00 - Last mean reward per episode: 38.98
# Num timesteps: 2000
# Best mean reward: 90.00 - Last mean reward per episode: 38.92
# Num timesteps: 2020
# Best mean reward: 90.00 - Last mean reward per episode: 38.77
# Num timesteps: 2040
# Best mean reward: 90.00 - Last mean reward per episode: 38.77
# Num timesteps: 2060
# Best mean reward: 90.00 - Last mean reward per episode: 38.77
# Num timesteps: 2080
# Best mean reward: 90.00 - Last mean reward per episode: 38.96
# Num timesteps: 2100
# Best mean reward: 90.00 - Last mean reward per episode: 38.96
# Num timesteps: 2120
# Best mean reward: 90.00 - Last mean reward per episode: 39.15
# Num timesteps: 2140
# Best mean reward: 90.00 - Last mean reward per episode: 39.15
# Num timesteps: 2160
# Best mean reward: 90.00 - Last mean reward per episode: 39.11
# Num timesteps: 2180
# Best mean reward: 90.00 - Last mean reward per episode: 39.11
# Num timesteps: 2200
# Best mean reward: 90.00 - Last mean reward per episode: 39.27
# Num timesteps: 2220
# Best mean reward: 90.00 - Last mean reward per episode: 39.27
# Num timesteps: 2240
# Best mean reward: 90.00 - Last mean reward per episode: 39.26
# Num timesteps: 2260
# Best mean reward: 90.00 - Last mean reward per episode: 39.26
# Num timesteps: 2280
# Best mean reward: 90.00 - Last mean reward per episode: 39.12
# Num timesteps: 2300
# Best mean reward: 90.00 - Last mean reward per episode: 39.12
# Num timesteps: 2320
# Best mean reward: 90.00 - Last mean reward per episode: 39.00
# Num timesteps: 2340
# Best mean reward: 90.00 - Last mean reward per episode: 38.68
# Num timesteps: 2360
# Best mean reward: 90.00 - Last mean reward per episode: 38.52
# Num timesteps: 2380
# Best mean reward: 90.00 - Last mean reward per episode: 38.29
# Num timesteps: 2400
# Best mean reward: 90.00 - Last mean reward per episode: 38.08
# Num timesteps: 2420
# Best mean reward: 90.00 - Last mean reward per episode: 38.08
# Num timesteps: 2440
# Best mean reward: 90.00 - Last mean reward per episode: 37.89
# Num timesteps: 2460
# Best mean reward: 90.00 - Last mean reward per episode: 37.78
# Num timesteps: 2480
# Best mean reward: 90.00 - Last mean reward per episode: 37.78
# Num timesteps: 2500
# Best mean reward: 90.00 - Last mean reward per episode: 37.83
# Num timesteps: 2520
# Best mean reward: 90.00 - Last mean reward per episode: 37.83
# Num timesteps: 2540
# Best mean reward: 90.00 - Last mean reward per episode: 37.83
# Num timesteps: 2560
# Best mean reward: 90.00 - Last mean reward per episode: 38.19
# Num timesteps: 2580
# Best mean reward: 90.00 - Last mean reward per episode: 38.19
# Num timesteps: 2600
# Best mean reward: 90.00 - Last mean reward per episode: 37.96
# Num timesteps: 2620
# Best mean reward: 90.00 - Last mean reward per episode: 37.96
# Num timesteps: 2640
# Best mean reward: 90.00 - Last mean reward per episode: 38.04
# Num timesteps: 2660
# Best mean reward: 90.00 - Last mean reward per episode: 38.04
# Num timesteps: 2680
# Best mean reward: 90.00 - Last mean reward per episode: 38.04
# Num timesteps: 2700
# Best mean reward: 90.00 - Last mean reward per episode: 37.99
# Num timesteps: 2720
# Best mean reward: 90.00 - Last mean reward per episode: 37.99
# Num timesteps: 2740
# Best mean reward: 90.00 - Last mean reward per episode: 38.04
# Num timesteps: 2760
# Best mean reward: 90.00 - Last mean reward per episode: 38.04
# Num timesteps: 2780
# Best mean reward: 90.00 - Last mean reward per episode: 37.90
# Num timesteps: 2800
# Best mean reward: 90.00 - Last mean reward per episode: 37.76
# Num timesteps: 2820
# Best mean reward: 90.00 - Last mean reward per episode: 37.76
# Num timesteps: 2840
# Best mean reward: 90.00 - Last mean reward per episode: 37.76
# Num timesteps: 2860
# Best mean reward: 90.00 - Last mean reward per episode: 38.01
# Num timesteps: 2880
# Best mean reward: 90.00 - Last mean reward per episode: 38.01
# Num timesteps: 2900
# Best mean reward: 90.00 - Last mean reward per episode: 38.12
# Num timesteps: 2920
# Best mean reward: 90.00 - Last mean reward per episode: 38.12
# Num timesteps: 2940
# Best mean reward: 90.00 - Last mean reward per episode: 38.12
# Num timesteps: 2960
# Best mean reward: 90.00 - Last mean reward per episode: 38.12
# Num timesteps: 2980
# Best mean reward: 90.00 - Last mean reward per episode: 38.60
# Num timesteps: 3000
# Best mean reward: 90.00 - Last mean reward per episode: 38.60
# Num timesteps: 3020
# Best mean reward: 90.00 - Last mean reward per episode: 38.60
# Num timesteps: 3040
# Best mean reward: 90.00 - Last mean reward per episode: 38.60
# Num timesteps: 3060
# Best mean reward: 90.00 - Last mean reward per episode: 38.60
# Num timesteps: 3080
# Best mean reward: 90.00 - Last mean reward per episode: 38.60
# Num timesteps: 3100
# Best mean reward: 90.00 - Last mean reward per episode: 39.56
# Num timesteps: 3120
# Best mean reward: 90.00 - Last mean reward per episode: 39.56
# Num timesteps: 3140
# Best mean reward: 90.00 - Last mean reward per episode: 39.66
# Num timesteps: 3160
# Best mean reward: 90.00 - Last mean reward per episode: 39.66
# Num timesteps: 3180
# Best mean reward: 90.00 - Last mean reward per episode: 39.75
# Num timesteps: 3200
# Best mean reward: 90.00 - Last mean reward per episode: 39.75
# Num timesteps: 3220
# Best mean reward: 90.00 - Last mean reward per episode: 39.75
# Num timesteps: 3240
# Best mean reward: 90.00 - Last mean reward per episode: 39.75
# Num timesteps: 3260
# Best mean reward: 90.00 - Last mean reward per episode: 39.75
# Num timesteps: 3280
# Best mean reward: 90.00 - Last mean reward per episode: 39.75
# Num timesteps: 3300
# Best mean reward: 90.00 - Last mean reward per episode: 39.75
# Num timesteps: 3320
# Best mean reward: 90.00 - Last mean reward per episode: 39.75
# Num timesteps: 3340
# Best mean reward: 90.00 - Last mean reward per episode: 39.75
# Num timesteps: 3360
# Best mean reward: 90.00 - Last mean reward per episode: 41.41
# Num timesteps: 3380
# Best mean reward: 90.00 - Last mean reward per episode: 41.41
# Num timesteps: 3400
# Best mean reward: 90.00 - Last mean reward per episode: 41.41
# Num timesteps: 3420
# Best mean reward: 90.00 - Last mean reward per episode: 41.41
# Num timesteps: 3440
# Best mean reward: 90.00 - Last mean reward per episode: 41.85
# Num timesteps: 3460
# Best mean reward: 90.00 - Last mean reward per episode: 41.85
# Num timesteps: 3480
# Best mean reward: 90.00 - Last mean reward per episode: 41.85
# Num timesteps: 3500
# Best mean reward: 90.00 - Last mean reward per episode: 41.85
# Num timesteps: 3520
# Best mean reward: 90.00 - Last mean reward per episode: 41.85
# Num timesteps: 3540
# Best mean reward: 90.00 - Last mean reward per episode: 41.85
# Num timesteps: 3560
# Best mean reward: 90.00 - Last mean reward per episode: 42.82
# Num timesteps: 3580
# Best mean reward: 90.00 - Last mean reward per episode: 42.82
# Num timesteps: 3600
# Best mean reward: 90.00 - Last mean reward per episode: 42.82
# Num timesteps: 3620
# Best mean reward: 90.00 - Last mean reward per episode: 42.82
# Num timesteps: 3640
# Best mean reward: 90.00 - Last mean reward per episode: 42.82
# Num timesteps: 3660
# Best mean reward: 90.00 - Last mean reward per episode: 42.82
# Num timesteps: 3680
# Best mean reward: 90.00 - Last mean reward per episode: 43.62
# Num timesteps: 3700
# Best mean reward: 90.00 - Last mean reward per episode: 43.62
# Num timesteps: 3720
# Best mean reward: 90.00 - Last mean reward per episode: 43.62
# Num timesteps: 3740
# Best mean reward: 90.00 - Last mean reward per episode: 43.62
# Num timesteps: 3760
# Best mean reward: 90.00 - Last mean reward per episode: 43.62
# Num timesteps: 3780
# Best mean reward: 90.00 - Last mean reward per episode: 43.62
# Num timesteps: 3800
# Best mean reward: 90.00 - Last mean reward per episode: 44.52
# Num timesteps: 3820
# Best mean reward: 90.00 - Last mean reward per episode: 44.52
# Num timesteps: 3840
# Best mean reward: 90.00 - Last mean reward per episode: 44.47
# Num timesteps: 3860
# Best mean reward: 90.00 - Last mean reward per episode: 44.47
# Num timesteps: 3880
# Best mean reward: 90.00 - Last mean reward per episode: 44.47
# Num timesteps: 3900
# Best mean reward: 90.00 - Last mean reward per episode: 44.79
# Num timesteps: 3920
# Best mean reward: 90.00 - Last mean reward per episode: 44.79
# Num timesteps: 3940
# Best mean reward: 90.00 - Last mean reward per episode: 44.73
# Num timesteps: 3960
# Best mean reward: 90.00 - Last mean reward per episode: 44.73
# Num timesteps: 3980
# Best mean reward: 90.00 - Last mean reward per episode: 44.73
# Num timesteps: 4000
# Best mean reward: 90.00 - Last mean reward per episode: 44.73
# Num timesteps: 4020
# Best mean reward: 90.00 - Last mean reward per episode: 44.73
# Num timesteps: 4040
# Best mean reward: 90.00 - Last mean reward per episode: 44.73
# Num timesteps: 4060
# Best mean reward: 90.00 - Last mean reward per episode: 45.42
# Num timesteps: 4080
# Best mean reward: 90.00 - Last mean reward per episode: 45.42
# Num timesteps: 4100
# Best mean reward: 90.00 - Last mean reward per episode: 45.42
# Num timesteps: 4120
# Best mean reward: 90.00 - Last mean reward per episode: 45.42
# Num timesteps: 4140
# Best mean reward: 90.00 - Last mean reward per episode: 45.42
# Num timesteps: 4160
# Best mean reward: 90.00 - Last mean reward per episode: 45.42
# Num timesteps: 4180
# Best mean reward: 90.00 - Last mean reward per episode: 45.42
# Num timesteps: 4200
# Best mean reward: 90.00 - Last mean reward per episode: 45.42
# Num timesteps: 4220
# Best mean reward: 90.00 - Last mean reward per episode: 45.42
# Num timesteps: 4240
# Best mean reward: 90.00 - Last mean reward per episode: 46.91
# Num timesteps: 4260
# Best mean reward: 90.00 - Last mean reward per episode: 46.91
# Num timesteps: 4280
# Best mean reward: 90.00 - Last mean reward per episode: 46.91
# Num timesteps: 4300
# Best mean reward: 90.00 - Last mean reward per episode: 46.91
# Num timesteps: 4320
# Best mean reward: 90.00 - Last mean reward per episode: 46.91
# Num timesteps: 4340
# Best mean reward: 90.00 - Last mean reward per episode: 46.91
# Num timesteps: 4360
# Best mean reward: 90.00 - Last mean reward per episode: 47.91
# Num timesteps: 4380
# Best mean reward: 90.00 - Last mean reward per episode: 47.91
# Num timesteps: 4400
# Best mean reward: 90.00 - Last mean reward per episode: 47.91
# Num timesteps: 4420
# Best mean reward: 90.00 - Last mean reward per episode: 47.91
# Num timesteps: 4440
# Best mean reward: 90.00 - Last mean reward per episode: 47.91
# Num timesteps: 4460
# Best mean reward: 90.00 - Last mean reward per episode: 47.91
# Num timesteps: 4480
# Best mean reward: 90.00 - Last mean reward per episode: 47.91
# Num timesteps: 4500
# Best mean reward: 90.00 - Last mean reward per episode: 48.77
# Num timesteps: 4520
# Best mean reward: 90.00 - Last mean reward per episode: 48.77
# Num timesteps: 4540
# Best mean reward: 90.00 - Last mean reward per episode: 48.77
# Num timesteps: 4560
# Best mean reward: 90.00 - Last mean reward per episode: 48.77
# Num timesteps: 4580
# Best mean reward: 90.00 - Last mean reward per episode: 49.08
# Num timesteps: 4600
# Best mean reward: 90.00 - Last mean reward per episode: 49.08
# Num timesteps: 4620
# Best mean reward: 90.00 - Last mean reward per episode: 49.08
# Num timesteps: 4640
# Best mean reward: 90.00 - Last mean reward per episode: 49.08
# Num timesteps: 4660
# Best mean reward: 90.00 - Last mean reward per episode: 49.08
# Num timesteps: 4680
# Best mean reward: 90.00 - Last mean reward per episode: 49.08
# Num timesteps: 4700
# Best mean reward: 90.00 - Last mean reward per episode: 49.95
# Num timesteps: 4720
# Best mean reward: 90.00 - Last mean reward per episode: 49.95
# Num timesteps: 4740
# Best mean reward: 90.00 - Last mean reward per episode: 49.95
# Num timesteps: 4760
# Best mean reward: 90.00 - Last mean reward per episode: 49.95
# Num timesteps: 4780
# Best mean reward: 90.00 - Last mean reward per episode: 49.95
# Num timesteps: 4800
# Best mean reward: 90.00 - Last mean reward per episode: 49.95
# Num timesteps: 4820
# Best mean reward: 90.00 - Last mean reward per episode: 49.95
# Num timesteps: 4840
# Best mean reward: 90.00 - Last mean reward per episode: 49.95
# Num timesteps: 4860
# Best mean reward: 90.00 - Last mean reward per episode: 49.95
# Num timesteps: 4880
# Best mean reward: 90.00 - Last mean reward per episode: 49.95
# Num timesteps: 4900
# Best mean reward: 90.00 - Last mean reward per episode: 51.43
# Num timesteps: 4920
# Best mean reward: 90.00 - Last mean reward per episode: 51.43
# Num timesteps: 4940
# Best mean reward: 90.00 - Last mean reward per episode: 51.43
# Num timesteps: 4960
# Best mean reward: 90.00 - Last mean reward per episode: 51.43
# Num timesteps: 4980
# Best mean reward: 90.00 - Last mean reward per episode: 51.43
# Num timesteps: 5000
# Best mean reward: 90.00 - Last mean reward per episode: 51.43
